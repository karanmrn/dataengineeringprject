# %%
import pandas as pd

# %%
df=pd.read_parquet("Downloads/yellow_tripdata_2021-01.parquet")

# %%
df.to_csv('yellow.csv')

# %%
df=pd.read_csv("yellow.csv",nrows=100)

# %%
df
# Out:
#     Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0            0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1            1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2            2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3            3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4            4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ..         ...       ...                  ...                   ...
# 95          95         2  2021-01-01 00:12:41   2021-01-01 00:26:47
# 96          96         2  2021-01-01 00:23:29   2021-01-01 00:35:03
# 97          97         2  2021-01-01 00:46:17   2021-01-01 00:54:25
# 98          98         2  2021-01-01 00:28:16   2021-01-01 00:51:44
# 99          99         2  2021-01-01 00:42:35   2021-01-01 00:54:41
#
#     passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0               1.0           2.10         1.0                  N
# 1               1.0           0.20         1.0                  N
# 2               1.0          14.70         1.0                  N
# 3               0.0          10.60         1.0                  N
# 4               1.0           4.94         1.0                  N
# ..              ...            ...         ...                ...
# 95              1.0           4.13         1.0                  N
# 96              2.0           4.12         1.0                  N
# 97              2.0           2.22         1.0                  N
# 98              1.0           7.11         1.0                  N
# 99              3.0           1.61         1.0                  N
#
#     PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0            142            43             2          8.0    3.0      0.5
# 1            238           151             2          3.0    0.5      0.5
# 2            132           165             1         42.0    0.5      0.5
# 3            138           132             1         29.0    0.5      0.5
# 4             68            33             1         16.5    0.5      0.5
# ..           ...           ...           ...          ...    ...      ...
# 95           161           226             1         14.5    0.5      0.5
# 96           162            74             2         13.5    0.5      0.5
# 97           144           170             1          9.0    0.5      0.5
# 98           264           264             2         23.5    0.5      0.5
# 99           229           237             2          9.5    0.5      0.5
#
#     tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0         0.00           0.0                    0.3         11.80
# 1         0.00           0.0                    0.3          4.30
# 2         8.65           0.0                    0.3         51.95
# 3         6.05           0.0                    0.3         36.35
# 4         4.06           0.0                    0.3         24.36
# ..         ...           ...                    ...           ...
# 95        3.66           0.0                    0.3         21.96
# 96        0.00           0.0                    0.3         17.30
# 97        2.56           0.0                    0.3         15.36
# 98        0.00           0.0                    0.3         24.80
# 99        0.00           0.0                    0.3         13.30
#
#     congestion_surcharge  airport_fee
# 0                    2.5          NaN
# 1                    0.0          NaN
# 2                    0.0          NaN
# 3                    0.0          NaN
# 4                    2.5          NaN
# ..                   ...          ...
# 95                   2.5          NaN
# 96                   2.5          NaN
# 97                   2.5          NaN
# 98                   0.0          NaN
# 99                   2.5          NaN
#
# [100 rows x 20 columns]

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"Unnamed: 0" BIGINT,
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df_iter = pd.read_csv('yellow.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
# Empty DataFrame
# Columns: [schemaname, tablename, tableowner, tablespace, hasindexes, hasrules, hastriggers, rowsecurity]
# Index: []

# %%
df.to_sql(name='yellow_tripdata_trip', con=engine, index=False)
# Out:
# 1000

# %%
query = """
SELECT * FROM yellow_tripdata_trip LIMIT 10
"""

pd.read_sql(query, con=engine)
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1           1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2           2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3           3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4           4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# 5           5         1  2021-01-01 00:16:29   2021-01-01 00:24:30
# 6           6         1  2021-01-01 00:00:28   2021-01-01 00:17:28
# 7           7         1  2021-01-01 00:12:29   2021-01-01 00:30:34
# 8           8         1  2021-01-01 00:39:16   2021-01-01 01:00:13
# 9           9         1  2021-01-01 00:26:12   2021-01-01 00:39:46
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           2.10         1.0                  N
# 1              1.0           0.20         1.0                  N
# 2              1.0          14.70         1.0                  N
# 3              0.0          10.60         1.0                  N
# 4              1.0           4.94         1.0                  N
# 5              1.0           1.60         1.0                  N
# 6              1.0           4.10         1.0                  N
# 7              1.0           5.70         1.0                  N
# 8              1.0           9.10         1.0                  N
# 9              2.0           2.70         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           142            43             2          8.0    3.0      0.5
# 1           238           151             2          3.0    0.5      0.5
# 2           132           165             1         42.0    0.5      0.5
# 3           138           132             1         29.0    0.5      0.5
# 4            68            33             1         16.5    0.5      0.5
# 5           224            68             1          8.0    3.0      0.5
# 6            95           157             2         16.0    0.5      0.5
# 7            90            40             2         18.0    3.0      0.5
# 8            97           129             4         27.5    0.5      0.5
# 9           263           142             1         12.0    3.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        0.00           0.0                    0.3         11.80
# 1        0.00           0.0                    0.3          4.30
# 2        8.65           0.0                    0.3         51.95
# 3        6.05           0.0                    0.3         36.35
# 4        4.06           0.0                    0.3         24.36
# 5        2.35           0.0                    0.3         14.15
# 6        0.00           0.0                    0.3         17.30
# 7        0.00           0.0                    0.3         21.80
# 8        0.00           0.0                    0.3         28.80
# 9        3.15           0.0                    0.3         18.95
#
#    congestion_surcharge airport_fee
# 0                   2.5        None
# 1                   0.0        None
# 2                   0.0        None
# 3                   0.0        None
# 4                   2.5        None
# 5                   2.5        None
# 6                   0.0        None
# 7                   2.5        None
# 8                   0.0        None
# 9                   2.5        None

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 3.35 s, sys: 211 ms, total: 3.57 s
# Wall time: 6.45 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 6.749 second
# inserted another chunk, took 6.157 second
# inserted another chunk, took 6.492 second
# inserted another chunk, took 6.163 second
# inserted another chunk, took 7.242 second
# inserted another chunk, took 6.934 second
# /var/folders/yj/1951c1j97n1dxzgvbv1z9k4m0000gn/T/ipykernel_14497/2113580993.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
# inserted another chunk, took 6.337 second
# inserted another chunk, took 6.135 second
# inserted another chunk, took 6.435 second
# inserted another chunk, took 6.626 second
# inserted another chunk, took 7.053 second
# /var/folders/yj/1951c1j97n1dxzgvbv1z9k4m0000gn/T/ipykernel_14497/2113580993.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk, took 6.962 second
# inserted another chunk, took 5.351 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[23], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       7     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# File /opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1668, in TextFileReader.__next__(self)
#    1666 def __next__(self) -> DataFrame:
#    1667     try:
# -> 1668         return self.get_chunk()
#    1669     except StopIteration:
#    1670         self.close()
#
# File /opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1777, in TextFileReader.get_chunk(self, size)
#    1775         raise StopIteration
#    1776     size = min(size, self.nrows - self._currow)
# -> 1777 return self.read(nrows=size)
#
# File /opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File /opt/homebrew/Cellar/jupyterlab/4.0.10/libexec/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:868, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
